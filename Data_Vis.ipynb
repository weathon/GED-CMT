# %% [markdown]
# <a href="https://colab.research.google.com/github/weathon/GED-CMT/blob/main/Data_Vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("main (2).csv")

# %%
df

# %%
df["Total Time"]=df["UBLB Time"]+df["Final Wash Time"]

# %%
(df["BF Found"]!=df["nFound"]).any()
# Out:
# False

# %%
pylab.scatter(df["nFound"]/df["Dataset Size"]*100, df["Total Time"]/df["BF Time"], c=df["Graph Size"])
pylab.colorbar(label="Graph Size")
pylab.xscale("log")
pylab.yscale("log")
pylab.imshow(np.ones((10000,110,3))*0.8, aspect='auto')
pylab.plot([0,100],[1,1], label="Break Even Line", color="red")
pylab.legend()
pylab.xlabel("% of Graphs Found in Total Dataset")
pylab.ylabel("CMT_Time/BF_Time")
pylab.title("Relationship Between Graph Size, Graph Found, and Relative Performance")
# Out:
# <ipython-input-54-6b8e3da6c161>:5: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   pylab.imshow(np.ones((10000,110,3))*0.8, aspect='auto')
# <ipython-input-54-6b8e3da6c161>:5: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   pylab.imshow(np.ones((10000,110,3))*0.8, aspect='auto')
# Text(0.5, 1.0, 'Relationship Between Graph Size, Graph Found, and Relative Performance')

# %%
import pylab
import numpy as np
pylab.rcParams["figure.figsize"] = (9,9)
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 500
pylab.style.use("bmh")
pylab.rcParams["font.family"] = "serif"
# pylab.imshow(np.ones((1750,35000,3))*0.8, aspect='auto')
pylab.scatter(df["Total Time"],df["BF Time"], c=df["nFound"]/df["Dataset Size"]*100, alpha=0.6)
pylab.plot([0,8000000],[0,8000000], color="red", label="Break Even Line")
pylab.xlim(0,35000)
pylab.ylim(0,1750)
pylab.colorbar(label="% of Graphs Found in Total Dataset")
pylab.xlabel("CMT Time (ms)")
pylab.ylabel("Brute Force Time (ms)")
pylab.title("Performance Comparison Between CMT and BF")
pylab.legend()
# pylab.savefig("nFound.png", dpi = 500)

# %%
import pylab
import numpy as np
index = 0
def get_marker():
  global index
  index+=1
  return ".,ov^<>123"[index]
def plot_box(x, y, color=None, label=None):
  pylab.yscale("log")
  ans = dict.fromkeys(set(x))
  for i in ans.keys():
    ans[i]=[]
  for i,j in zip(x,y):
    ans[i].append(j)
  mean = [np.mean(ans[i]) for i in ans.keys()]
  std = [1.96*np.std(ans[i], ddof=1)/np.sqrt(len(ans[i])) for i in ans.keys()]
  pylab.errorbar(ans.keys(), mean, yerr=std, label=label, alpha=0.5, marker=get_marker(), color=color)
  pylab.ylim(0)

# %%
pylab.rcParams["figure.figsize"] = (5,5)
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 500
index = 0
pylab.style.use("ggplot")
for gs in sorted(set(df["Graph Size"])):
  ds=500
  tmp = df[(df["Graph Size"]==gs) & (df["Dataset Size"]==ds)]
  plot_box(tmp["r"],tmp["Total Time"]/tmp["BF Time"],label=f"Graph Size={gs}, Dataset Size={ds}")
index = 0
# for ds in sorted(set(df[df["Graph Size"]==7]["Dataset Size"])):
#   gs=7
#   if ds==1500:
#     continue
#   tmp = df[(df["Graph Size"]==gs) & (df["Dataset Size"]==ds)]
#   plot_box(tmp["r"],tmp["Total Time"]/tmp["BF Time"],np.array((0,0,1))*(1-index), label=f"Graph Size={gs}, Dataset Size={ds}")


pylab.xlabel("Search Radius")
pylab.ylabel("CMT_Time/BF_Time")
# pylab.title("Effects of UBLB Itterations on Releative Perfomance")
pylab.legend()
pylab.yscale("log")
pylab.title("Performance Comparison for Different Parameters")
pylab.ylim(0,5000)
# Out:
# <ipython-input-10-0971d121a010>:18: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   pylab.ylim(0)
# <ipython-input-20-cc71e5cbaa9f>:25: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   pylab.ylim(0,5000)
# (0.02017407132840473, 5000)

# %%
set(df["Dataset Size"])
# Out:
# {500, 804, 1500, 1728, 2500, 2936}

# %%
index = 0
import random
for ds in sorted(set(df[df["Graph Size"]==9]["Dataset Size"])):
  gs=9
  # if ds==1500:
  #   continue
  tmp = df[(df["Graph Size"]==gs) & (df["Dataset Size"]==ds)]
  plot_box(tmp["r"],tmp["Total Time"]/tmp["BF Time"], label=f"Graph Size={gs}, Dataset Size={ds}")


pylab.xlabel("Search Radius")
pylab.ylabel("CMT_Time/BF_Time")
# pylab.title("Effects of UBLB Itterations on Releative Perfomance")
pylab.legend()
pylab.yscale("log")
pylab.title("Performance Comparison for Different Parameters")
pylab.ylim(0,1000)
#why same graph? we can do two
# Out:
# <ipython-input-10-0971d121a010>:18: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   pylab.ylim(0)
# <ipython-input-21-d84ecccc2959>:17: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   pylab.ylim(0,1000)
# (12.966148588428986, 1000)

# %%
pylab.style.available #koukeduziyuanlaiyouhenduo binageduo
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import numpy as np
import pylab
# import matplotlib as mpl
# mpl.rcParams.update(mpl.rcParamsDefault)
pylab.style.use("seaborn-v0_8-pastel")
pylab.rcParams["font.family"] = "serif"
# pylab.imshow(np.ones((500,500,3))*0.8)
pylab.scatter(df["Total Time"],df["BF Time"], c=df["nFound"]/df["Dataset Size"]*100, alpha=1, cmap="viridis")
pylab.plot([0,8000000],[0,8000000], color="red", label="Break Even Line")
pylab.xlim(0,8000)
pylab.ylim(0,1000)
pylab.colorbar(label="% of Graphs Found in Total Dataset")
pylab.xlabel("CMT Time (ms)")
pylab.ylabel("Brute Force Time (ms)")
pylab.title("Performance Comparison Between CMT and Brute Force (Zoomed In)")
pylab.legend()
pylab.savefig("nFound.png", dpi = 500, bbox_inches='tight')

# %%
from PIL import Image
import numpy as np
img = np.array(Image.open("nFound.png").convert("RGB"))
mask = np.sum(img, axis=-1)<10 #forget==0
mask2 = np.sum(img, axis=-1)>=250*3 #forget==0
img[mask] = (220,220,220)
img[mask2] = (0,0,0)

# %%
mask

# %%
import pylab
pylab.imshow(img)
Image.fromarray(img).save("2.png")

# %%
import numpy as np
pylab.hist(df["Total Time"]/df["BF Time"], bins=np.arange(0,10,1))
